# %%
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service


driver=webdriver.Chrome(r'C:\SeleniumDriver\chromedriver.exe')


driver.get("https://en.wikipedia.org/wiki/Main_Page")


TFA_CSS_LOCATOR="div#mp-tfa"
DYK_CSS_LOCATOR="div#mp-dyk"
ITN_CSS_LOCATOR="div#mp-itn"
OTD_CSS_LOCATOR="div#mp-otd"


locator_list=[TFA_CSS_LOCATOR,DYK_CSS_LOCATOR,ITN_CSS_LOCATOR,OTD_CSS_LOCATOR]
link_dictionary={}
# Out:
# C:\Users\dsandpa\AppData\Local\Temp/ipykernel_25520/2054682584.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\SeleniumDriver\chromedriver.exe')

# %%
for locator in locator_list:
    
    div_element=driver.find_element(By.CSS_SELECTOR,locator)
    
    info_list=[]
    for link in div_element.find_elements(By.TAG_NAME,'a'):
    
        info_dict={'title':link.get_attribute('title'),
                    'href':link.get_attribute('href'),
                    'text':link.text
                   
                  }

        info_list.append(info_dict)
    
    
    link_dictionary[locator]=info_list

# %%
link_dictionary[TFA_CSS_LOCATOR]
# Out:
# [{'title': 'Modern depiction of a Roman siege engine during the siege of Carthage',
#   'href': 'https://en.wikipedia.org/wiki/File:Catapulta_by_Edward_Poynter.jpg',
#   'text': ''},
#  {'title': 'Siege engine',
#   'href': 'https://en.wikipedia.org/wiki/Siege_engine',
#   'text': 'siege engine'},
#  {'title': 'Siege of Carthage (Third Punic War)',
#   'href': 'https://en.wikipedia.org/wiki/Siege_of_Carthage_(Third_Punic_War)',
#   'text': 'siege of Carthage'},
#  {'title': 'Third Punic War',
#   'href': 'https://en.wikipedia.org/wiki/Third_Punic_War',
#   'text': 'Third Punic War'},
#  {'title': 'Punic Wars',
#   'href': 'https://en.wikipedia.org/wiki/Punic_Wars',
#   'text': 'Punic Wars'},
#  {'title': 'Ancient Carthage',
#   'href': 'https://en.wikipedia.org/wiki/Ancient_Carthage',
#   'text': 'Carthage'},
#  {'title': 'Roman Republic',
#   'href': 'https://en.wikipedia.org/wiki/Roman_Republic',
#   'text': 'Rome'},
#  {'title': 'Siege',
#   'href': 'https://en.wikipedia.org/wiki/Siege',
#   'text': 'besiege'},
#  {'title': 'Carthage',
#   'href': 'https://en.wikipedia.org/wiki/Carthage',
#   'text': 'Carthage'},
#  {'title': 'Scipio Aemilianus',
#   'href': 'https://en.wikipedia.org/wiki/Scipio_Aemilianus',
#   'text': 'Scipio Aemilianus'},
#  {'title': 'Africa (Roman province)',
#   'href': 'https://en.wikipedia.org/wiki/Africa_(Roman_province)',
#   'text': 'Roman province of Africa'},
#  {'title': 'Third Punic War',
#   'href': 'https://en.wikipedia.org/wiki/Third_Punic_War',
#   'text': 'This article'},
#  {'title': 'Wikipedia:Featured topics',
#   'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_topics',
#   'text': 'featured topic'},
#  {'title': 'Wikipedia:Featured topics/Punic Wars',
#   'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_topics/Punic_Wars',
#   'text': 'Punic Wars'},
#  {'title': 'Alfred Russel Wallace',
#   'href': 'https://en.wikipedia.org/wiki/Alfred_Russel_Wallace',
#   'text': 'Alfred Russel Wallace'},
#  {'title': 'Charles I of Anjou',
#   'href': 'https://en.wikipedia.org/wiki/Charles_I_of_Anjou',
#   'text': 'Charles I of Anjou'},
#  {'title': 'London and North Western Railway War Memorial',
#   'href': 'https://en.wikipedia.org/wiki/London_and_North_Western_Railway_War_Memorial',
#   'text': 'London and North Western Railway War Memorial'},
#  {'title': "Wikipedia:Today's featured article/January 2023",
#   'href': 'https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/January_2023',
#   'text': 'Archive'},
#  {'title': 'mail:daily-article-l',
#   'href': 'https://lists.wikimedia.org/postorius/lists/daily-article-l.lists.wikimedia.org/',
#   'text': 'By email'},
#  {'title': 'Wikipedia:Featured articles',
#   'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_articles',
#   'text': 'More featured articles'},
#  {'title': "Wikipedia:About Today's featured article",
#   'href': 'https://en.wikipedia.org/wiki/Wikipedia:About_Today%27s_featured_article',
#   'text': 'About'}]

# %%
link_dictionary
# Out:
# {'div#mp-tfa': [{'title': 'Modern depiction of a Roman siege engine during the siege of Carthage',
#    'href': 'https://en.wikipedia.org/wiki/File:Catapulta_by_Edward_Poynter.jpg',
#    'text': ''},
#   {'title': 'Siege engine',
#    'href': 'https://en.wikipedia.org/wiki/Siege_engine',
#    'text': 'siege engine'},
#   {'title': 'Siege of Carthage (Third Punic War)',
#    'href': 'https://en.wikipedia.org/wiki/Siege_of_Carthage_(Third_Punic_War)',
#    'text': 'siege of Carthage'},
#   {'title': 'Third Punic War',
#    'href': 'https://en.wikipedia.org/wiki/Third_Punic_War',
#    'text': 'Third Punic War'},
#   {'title': 'Punic Wars',
#    'href': 'https://en.wikipedia.org/wiki/Punic_Wars',
#    'text': 'Punic Wars'},
#   {'title': 'Ancient Carthage',
#    'href': 'https://en.wikipedia.org/wiki/Ancient_Carthage',
#    'text': 'Carthage'},
#   {'title': 'Roman Republic',
#    'href': 'https://en.wikipedia.org/wiki/Roman_Republic',
#    'text': 'Rome'},
#   {'title': 'Siege',
#    'href': 'https://en.wikipedia.org/wiki/Siege',
#    'text': 'besiege'},
#   {'title': 'Carthage',
#    'href': 'https://en.wikipedia.org/wiki/Carthage',
#    'text': 'Carthage'},
#   {'title': 'Scipio Aemilianus',
#    'href': 'https://en.wikipedia.org/wiki/Scipio_Aemilianus',
#    'text': 'Scipio Aemilianus'},
#   {'title': 'Africa (Roman province)',
#    'href': 'https://en.wikipedia.org/wiki/Africa_(Roman_province)',
#    'text': 'Roman province of Africa'},
#   {'title': 'Third Punic War',
#    'href': 'https://en.wikipedia.org/wiki/Third_Punic_War',
#    'text': 'This article'},
#   {'title': 'Wikipedia:Featured topics',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_topics',
#    'text': 'featured topic'},
#   {'title': 'Wikipedia:Featured topics/Punic Wars',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_topics/Punic_Wars',
#    'text': 'Punic Wars'},
#   {'title': 'Alfred Russel Wallace',
#    'href': 'https://en.wikipedia.org/wiki/Alfred_Russel_Wallace',
#    'text': 'Alfred Russel Wallace'},
#   {'title': 'Charles I of Anjou',
#    'href': 'https://en.wikipedia.org/wiki/Charles_I_of_Anjou',
#    'text': 'Charles I of Anjou'},
#   {'title': 'London and North Western Railway War Memorial',
#    'href': 'https://en.wikipedia.org/wiki/London_and_North_Western_Railway_War_Memorial',
#    'text': 'London and North Western Railway War Memorial'},
#   {'title': "Wikipedia:Today's featured article/January 2023",
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/January_2023',
#    'text': 'Archive'},
#   {'title': 'mail:daily-article-l',
#    'href': 'https://lists.wikimedia.org/postorius/lists/daily-article-l.lists.wikimedia.org/',
#    'text': 'By email'},
#   {'title': 'Wikipedia:Featured articles',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Featured_articles',
#    'text': 'More featured articles'},
#   {'title': "Wikipedia:About Today's featured article",
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:About_Today%27s_featured_article',
#    'text': 'About'}],
#  'div#mp-dyk': [{'title': 'Sigismund Mohr',
#    'href': 'https://en.wikipedia.org/wiki/File:Sigismund_Mohr.jpg',
#    'text': ''},
#   {'title': 'Sigismund Mohr',
#    'href': 'https://en.wikipedia.org/wiki/Sigismund_Mohr',
#    'text': 'Sigismund Mohr'},
#   {'title': 'Quebec City',
#    'href': 'https://en.wikipedia.org/wiki/Quebec_City',
#    'text': 'Quebec City'},
#   {'title': 'Meghan Trainor',
#    'href': 'https://en.wikipedia.org/wiki/Meghan_Trainor',
#    'text': 'Meghan Trainor'},
#   {'title': 'Bad for Me (Meghan Trainor song)',
#    'href': 'https://en.wikipedia.org/wiki/Bad_for_Me_(Meghan_Trainor_song)',
#    'text': 'Bad for Me'},
#   {'title': 'Boxcar',
#    'href': 'https://en.wikipedia.org/wiki/Boxcar',
#    'text': 'boxcars'},
#   {'title': 'William W. Jefferis',
#    'href': 'https://en.wikipedia.org/wiki/William_W._Jefferis',
#    'text': 'William W. Jefferis'},
#   {'title': 'Carnegie Museum of Natural History',
#    'href': 'https://en.wikipedia.org/wiki/Carnegie_Museum_of_Natural_History',
#    'text': 'Carnegie Museum of Natural History'},
#   {'title': 'Viktor Kožený',
#    'href': 'https://en.wikipedia.org/wiki/Viktor_Ko%C5%BEen%C3%BD',
#    'text': 'Viktor Kožený'},
#   {'title': 'Fox Hill Prison',
#    'href': 'https://en.wikipedia.org/wiki/Fox_Hill_Prison',
#    'text': 'Fox Hill Prison'},
#   {'title': 'Astrakhan',
#    'href': 'https://en.wikipedia.org/wiki/Astrakhan',
#    'text': 'Astrakhan'},
#   {'title': 'Aleksandr Trusov',
#    'href': 'https://en.wikipedia.org/wiki/Aleksandr_Trusov',
#    'text': 'Aleksandr Trusov'},
#   {'title': 'Lady Gaga',
#    'href': 'https://en.wikipedia.org/wiki/Lady_Gaga',
#    'text': 'Lady Gaga'},
#   {'title': 'Free Woman',
#    'href': 'https://en.wikipedia.org/wiki/Free_Woman',
#    'text': 'Free Woman'},
#   {'title': 'Three-Self Patriotic Movement',
#    'href': 'https://en.wikipedia.org/wiki/Three-Self_Patriotic_Movement',
#    'text': 'Three-Self Patriotic Movement'},
#   {'title': 'Jia Yuming',
#    'href': 'https://en.wikipedia.org/wiki/Jia_Yuming',
#    'text': 'Jia Yuming'},
#   {'title': 'Secor, Iowa',
#    'href': 'https://en.wikipedia.org/wiki/Secor,_Iowa',
#    'text': 'Secor'},
#   {'title': 'Wikipedia:Recent additions',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Recent_additions',
#    'text': 'Archive'},
#   {'title': 'Help:Your first article',
#    'href': 'https://en.wikipedia.org/wiki/Help:Your_first_article',
#    'text': 'Start a new article'},
#   {'title': 'Template talk:Did you know',
#    'href': 'https://en.wikipedia.org/wiki/Template_talk:Did_you_know',
#    'text': 'Nominate an article'}],
#  'div#mp-itn': [{'title': 'Michael Smith in 2019',
#    'href': 'https://en.wikipedia.org/wiki/File:Michael_Smith_6-3_Steve_Lennon_-_Michael_Smith_-_2019249215712_2019-09-06_PDC_European_Darts_Matchplay_-_1108_-_B70I6125_(cropped).jpg',
#    'text': ''},
#   {'title': 'Jair Bolsonaro',
#    'href': 'https://en.wikipedia.org/wiki/Jair_Bolsonaro',
#    'text': 'Jair Bolsonaro'},
#   {'title': '2023 Praça dos Três Poderes attack',
#    'href': 'https://en.wikipedia.org/wiki/2023_Pra%C3%A7a_dos_Tr%C3%AAs_Poderes_attack',
#    'text': 'invade'},
#   {'title': 'National Congress of Brazil',
#    'href': 'https://en.wikipedia.org/wiki/National_Congress_of_Brazil',
#    'text': 'National Congress'},
#   {'title': 'Supreme Federal Court',
#    'href': 'https://en.wikipedia.org/wiki/Supreme_Federal_Court',
#    'text': 'Supreme Federal Court'},
#   {'title': 'Palácio do Planalto',
#    'href': 'https://en.wikipedia.org/wiki/Pal%C3%A1cio_do_Planalto',
#    'text': 'Palácio do Planalto'},
#   {'title': 'Michael Smith (darts player)',
#    'href': 'https://en.wikipedia.org/wiki/Michael_Smith_(darts_player)',
#    'text': 'Michael Smith'},
#   {'title': '2023 PDC World Darts Championship',
#    'href': 'https://en.wikipedia.org/wiki/2023_PDC_World_Darts_Championship',
#    'text': 'the PDC World Darts Championship'},
#   {'title': 'Croatia and the euro',
#    'href': 'https://en.wikipedia.org/wiki/Croatia_and_the_euro',
#    'text': 'adopts the euro'},
#   {'title': 'Schengen Area',
#    'href': 'https://en.wikipedia.org/wiki/Schengen_Area',
#    'text': 'Schengen Area'},
#   {'title': 'Pope',
#    'href': 'https://en.wikipedia.org/wiki/Pope',
#    'text': 'Pope'},
#   {'title': 'Pope Benedict XVI',
#    'href': 'https://en.wikipedia.org/wiki/Pope_Benedict_XVI',
#    'text': 'Benedict XVI'},
#   {'title': 'Death and funeral of Pope Benedict XVI',
#    'href': 'https://en.wikipedia.org/wiki/Death_and_funeral_of_Pope_Benedict_XVI',
#    'text': 'dies'},
#   {'title': 'Pelé',
#    'href': 'https://en.wikipedia.org/wiki/Pel%C3%A9',
#    'text': 'Pelé'},
#   {'title': 'Death and funeral of Pelé',
#    'href': 'https://en.wikipedia.org/wiki/Death_and_funeral_of_Pel%C3%A9',
#    'text': 'dies'},
#   {'title': 'Portal:Current events',
#    'href': 'https://en.wikipedia.org/wiki/Portal:Current_events',
#    'text': 'Ongoing'},
#   {'title': 'Mahsa Amini protests',
#    'href': 'https://en.wikipedia.org/wiki/Mahsa_Amini_protests',
#    'text': 'Mahsa Amini protests'},
#   {'title': '2022–2023 Peruvian political protests',
#    'href': 'https://en.wikipedia.org/wiki/2022%E2%80%932023_Peruvian_political_protests',
#    'text': 'Peruvian protests'},
#   {'title': '2022 Russian invasion of Ukraine',
#    'href': 'https://en.wikipedia.org/wiki/2022_Russian_invasion_of_Ukraine',
#    'text': 'Russian invasion of Ukraine'},
#   {'title': 'Deaths in 2023',
#    'href': 'https://en.wikipedia.org/wiki/Deaths_in_2023',
#    'text': 'Recent deaths'},
#   {'title': 'Danny Kaleikini',
#    'href': 'https://en.wikipedia.org/wiki/Danny_Kaleikini',
#    'text': 'Danny Kaleikini'},
#   {'title': 'Siddeshwar Swami',
#    'href': 'https://en.wikipedia.org/wiki/Siddeshwar_Swami',
#    'text': 'Siddeshwar Swami'},
#   {'title': 'Frank McGarvey',
#    'href': 'https://en.wikipedia.org/wiki/Frank_McGarvey',
#    'text': 'Frank McGarvey'},
#   {'title': 'Martin Davis (mathematician)',
#    'href': 'https://en.wikipedia.org/wiki/Martin_Davis_(mathematician)',
#    'text': 'Martin Davis'},
#   {'title': 'Andrew Downes (composer)',
#    'href': 'https://en.wikipedia.org/wiki/Andrew_Downes_(composer)',
#    'text': 'Andrew Downes'},
#   {'title': 'Gianluca Vialli',
#    'href': 'https://en.wikipedia.org/wiki/Gianluca_Vialli',
#    'text': 'Gianluca Vialli'},
#   {'title': 'Wikipedia:In the news/Candidates',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:In_the_news/Candidates',
#    'text': 'Nominate an article'}],
#  'div#mp-otd': [{'title': 'January 9',
#    'href': 'https://en.wikipedia.org/wiki/January_9',
#    'text': 'January 9'},
#   {'title': 'Coming of Age Day',
#    'href': 'https://en.wikipedia.org/wiki/Coming_of_Age_Day',
#    'text': 'Coming of Age Day'},
#   {'title': 'Ernest Shackleton and his team with the British flag',
#    'href': 'https://en.wikipedia.org/wiki/File:Nimrod_South_9_Jan_09.jpg',
#    'text': ''},
#   {'title': '1874',
#    'href': 'https://en.wikipedia.org/wiki/1874',
#    'text': '1874'},
#   {'title': 'Tokyo Metropolitan Police Department',
#    'href': 'https://en.wikipedia.org/wiki/Tokyo_Metropolitan_Police_Department',
#    'text': 'Tokyo Metropolitan Police Department'},
#   {'title': 'Kawaji Toshiyoshi',
#    'href': 'https://en.wikipedia.org/wiki/Kawaji_Toshiyoshi',
#    'text': 'Kawaji Toshiyoshi'},
#   {'title': '1909',
#    'href': 'https://en.wikipedia.org/wiki/1909',
#    'text': '1909'},
#   {'title': 'Ernest Shackleton',
#    'href': 'https://en.wikipedia.org/wiki/Ernest_Shackleton',
#    'text': 'Ernest Shackleton'},
#   {'title': 'Nimrod Expedition',
#    'href': 'https://en.wikipedia.org/wiki/Nimrod_Expedition',
#    'text': 'Nimrod Expedition'},
#   {'title': 'Farthest South',
#    'href': 'https://en.wikipedia.org/wiki/Farthest_South',
#    'text': 'farthest south'},
#   {'title': '1970',
#    'href': 'https://en.wikipedia.org/wiki/1970',
#    'text': '1970'},
#   {'title': 'Presidential Council for Minority Rights',
#    'href': 'https://en.wikipedia.org/wiki/Presidential_Council_for_Minority_Rights',
#    'text': 'Presidential Council for Minority Rights'},
#   {'title': '1978',
#    'href': 'https://en.wikipedia.org/wiki/1978',
#    'text': '1978'},
#   {'title': 'Iranian Revolution',
#    'href': 'https://en.wikipedia.org/wiki/Iranian_Revolution',
#    'text': 'Iranian Revolution'},
#   {'title': '1978 Qom protest',
#    'href': 'https://en.wikipedia.org/wiki/1978_Qom_protest',
#    'text': 'Protests took place'},
#   {'title': 'Qom', 'href': 'https://en.wikipedia.org/wiki/Qom', 'text': 'Qom'},
#   {'title': 'Iran and Red and Black Colonization',
#    'href': 'https://en.wikipedia.org/wiki/Iran_and_Red_and_Black_Colonization',
#    'text': 'an article'},
#   {'title': 'Ruhollah Khomeini',
#    'href': 'https://en.wikipedia.org/wiki/Ruhollah_Khomeini',
#    'text': 'Ruhollah Khomeini'},
#   {'title': '1991',
#    'href': 'https://en.wikipedia.org/wiki/1991',
#    'text': '1991'},
#   {'title': 'Geneva Peace Conference (1991)',
#    'href': 'https://en.wikipedia.org/wiki/Geneva_Peace_Conference_(1991)',
#    'text': 'the Geneva Peace Conference'},
#   {'title': 'Iraqi invasion of Kuwait',
#    'href': 'https://en.wikipedia.org/wiki/Iraqi_invasion_of_Kuwait',
#    'text': 'invasion of Kuwait'},
#   {'title': 'William Dugard',
#    'href': 'https://en.wikipedia.org/wiki/William_Dugard',
#    'text': 'William Dugard'},
#   {'title': 'Samuel Gridley Howe',
#    'href': 'https://en.wikipedia.org/wiki/Samuel_Gridley_Howe',
#    'text': 'Samuel Gridley Howe'},
#   {'title': 'Makinti Napanangka',
#    'href': 'https://en.wikipedia.org/wiki/Makinti_Napanangka',
#    'text': 'Makinti Napanangka'},
#   {'title': 'January 8',
#    'href': 'https://en.wikipedia.org/wiki/January_8',
#    'text': 'January 8'},
#   {'title': 'January 9',
#    'href': 'https://en.wikipedia.org/wiki/January_9',
#    'text': 'January 9'},
#   {'title': 'January 10',
#    'href': 'https://en.wikipedia.org/wiki/January_10',
#    'text': 'January 10'},
#   {'title': 'Wikipedia:Selected anniversaries/January',
#    'href': 'https://en.wikipedia.org/wiki/Wikipedia:Selected_anniversaries/January',
#    'text': 'Archive'},
#   {'title': 'mail:daily-article-l',
#    'href': 'https://lists.wikimedia.org/postorius/lists/daily-article-l.lists.wikimedia.org/',
#    'text': 'By email'},
#   {'title': 'List of days of the year',
#    'href': 'https://en.wikipedia.org/wiki/List_of_days_of_the_year',
#    'text': 'List of days of the year'}]}
